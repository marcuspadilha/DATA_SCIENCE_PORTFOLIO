# %% [markdown]
# # Dealing with the dataset

# %% [markdown]
# #### Importing the dataset

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\marcu\Desktop\MACHINE_LEARNING\DATABASES\BEER_RECIPES_DATASET\recipeData.csv', encoding='latin1')
data
# Out:
#        BeerID                             Name  \
# 0           1                Vanilla Cream Ale
# 1           2      Southern Tier Pumking clone
# 2           3      Zombie Dust Clone - EXTRACT
# 3           4    Zombie Dust Clone - ALL GRAIN
# 4           5  Bakke Brygg Belgisk Blonde 50 l
# ...       ...                              ...
# 73856   73857                    Amber Alfie 2
# 73857   73858                          Rye IPA
# 73858   73859                        SK-Kölsch
# 73859   73860                  Flata Rødkløver
# 73860   73861            Elvis Juice IPA Clone
#
#                                                      URL  \
# 0           /homebrew/recipe/view/1633/vanilla-cream-ale
# 1      /homebrew/recipe/view/16367/southern-tier-pumk...
# 2      /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3      /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4      /homebrew/recipe/view/89534/bakke-brygg-belgis...
# ...                                                  ...
# 73856         /homebrew/recipe/view/609673/amber-alfie-2
# 73857               /homebrew/recipe/view/610955/rye-ipa
# 73858                      /homebrew/recipe/view/586891/
# 73859                      /homebrew/recipe/view/603788/
# 73860  /homebrew/recipe/view/613776/elvis-juice-ipa-c...
#
#                                     Style  StyleID  Size(L)     OG     FG  \
# 0                               Cream Ale       45    21.77  1.055  1.013
# 1      Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021
# 2                            American IPA        7    18.93  1.063  1.018
# 3                            American IPA        7    22.71  1.061  1.017
# 4                       Belgian Blond Ale       20    50.00  1.060  1.010
# ...                                   ...      ...      ...    ...    ...
# 73856                  British Strong Ale       36    21.00  1.052  1.012
# 73857              Specialty IPA: Rye IPA      151    10.00  1.059  1.010
# 73858                                 NaN      111    16.00  1.046  1.008
# 73859                       Irish Red Ale       92    24.00  1.051  1.014
# 73860                        American IPA        7    20.00  1.060  1.010
#
#         ABV    IBU  ...  BoilGravity  Efficiency  MashThickness  \
# 0      5.48  17.65  ...        1.038        70.0            NaN
# 1      8.16  60.65  ...        1.070        70.0            NaN
# 2      5.91  59.25  ...          NaN        70.0            NaN
# 3      5.80  54.48  ...          NaN        70.0            NaN
# 4      6.48  17.84  ...        1.050        72.0            NaN
# ...     ...    ...  ...          ...         ...            ...
# 73856  5.22  39.73  ...        1.060        63.0            3.0
# 73857  6.37  59.21  ...        1.034        60.0            NaN
# 73858  5.01  25.42  ...        1.041        65.0            NaN
# 73859  4.82  25.65  ...        1.043        72.0            NaN
# 73860  6.55  57.09  ...        1.056        70.0            NaN
#
#              SugarScale    BrewMethod  PitchRate PrimaryTemp PrimingMethod  \
# 0      Specific Gravity     All Grain        NaN       17.78    corn sugar
# 1      Specific Gravity     All Grain        NaN         NaN           NaN
# 2      Specific Gravity       extract        NaN         NaN           NaN
# 3      Specific Gravity     All Grain        NaN         NaN           NaN
# 4      Specific Gravity     All Grain        NaN       19.00    Sukkerlake
# ...                 ...           ...        ...         ...           ...
# 73856  Specific Gravity     All Grain       1.25       20.00           NaN
# 73857  Specific Gravity          BIAB       0.50       22.00           NaN
# 73858  Specific Gravity          BIAB       0.35       17.00       sucrose
# 73859  Specific Gravity     All Grain        NaN       18.00    Sukkerlake
# 73860  Specific Gravity  Partial Mash        NaN       18.00           NaN
#
#         PrimingAmount   UserId
# 0              4.5 oz    116.0
# 1                 NaN    955.0
# 2                 NaN      NaN
# 3                 NaN      NaN
# 4      6-7 g sukker/l  18325.0
# ...               ...      ...
# 73856             NaN  59658.0
# 73857             NaN      NaN
# 73858           140 g  82450.0
# 73859    5 g sukker/l      NaN
# 73860             NaN      NaN
#
# [73861 rows x 23 columns]

# %% [markdown]
# #### Verifiying the dataset

# %%
data.isnull().sum()
# Out:
# BeerID           0
# StyleID          0
# Size(L)          0
# OG               0
# FG               0
# ABV              0
# IBU              0
# Color            0
# BoilSize         0
# BoilTime         0
# BoilGravity      0
# Efficiency       0
# MashThickness    0
# SugarScale       0
# BrewMethod       0
# PitchRate        0
# PrimaryTemp      0
# dtype: int64

# %%
missing_percent = (data.isnull().sum()/len(data['BeerID']))*100
missing_percent
# Out:
# BeerID           0.0
# StyleID          0.0
# Size(L)          0.0
# OG               0.0
# FG               0.0
# ABV              0.0
# IBU              0.0
# Color            0.0
# BoilSize         0.0
# BoilTime         0.0
# BoilGravity      0.0
# Efficiency       0.0
# MashThickness    0.0
# SugarScale       0.0
# BrewMethod       0.0
# PitchRate        0.0
# PrimaryTemp      0.0
# dtype: float64

# %%
data.dtypes
# Out:
# BeerID             int64
# StyleID            int64
# Size(L)          float64
# OG               float64
# FG               float64
# ABV              float64
# IBU              float64
# Color            float64
# BoilSize         float64
# BoilTime           int64
# BoilGravity      float64
# Efficiency       float64
# MashThickness    float64
# SugarScale        object
# BrewMethod        object
# PitchRate        float64
# PrimaryTemp      float64
# dtype: object

# %% [markdown]
# #### Manipulating the dataset

# %%
data.drop(['URL','Name', 'Style','PrimingMethod','PrimingAmount', 'UserId' ], inplace =True, axis = 1)
data

# %%
data['BoilGravity'].fillna(data['BoilGravity'].mean(), inplace = True)
data['MashThickness'].fillna(data['MashThickness'].mean(), inplace = True)
data['PitchRate'].fillna(data['PitchRate'].mean(), inplace = True)
data['PrimaryTemp'].fillna(data['PrimaryTemp'].mean(), inplace = True)
data
# Out:
#        BeerID  StyleID  Size(L)     OG     FG   ABV    IBU  Color  BoilSize  \
# 0           1       45    21.77  1.055  1.013  5.48  17.65   4.83     28.39
# 1           2       85    20.82  1.083  1.021  8.16  60.65  15.64     24.61
# 2           3        7    18.93  1.063  1.018  5.91  59.25   8.98     22.71
# 3           4        7    22.71  1.061  1.017  5.80  54.48   8.50     26.50
# 4           5       20    50.00  1.060  1.010  6.48  17.84   4.57     60.00
# ...       ...      ...      ...    ...    ...   ...    ...    ...       ...
# 73856   73857       36    21.00  1.052  1.012  5.22  39.73   6.96     18.00
# 73857   73858      151    10.00  1.059  1.010  6.37  59.21   7.90     17.00
# 73858   73859      111    16.00  1.046  1.008  5.01  25.42   3.63     18.00
# 73859   73860       92    24.00  1.051  1.014  4.82  25.65  14.12     28.00
# 73860   73861        7    20.00  1.060  1.010  6.55  57.09   8.65     12.00
#
#        BoilTime  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 0            75     1.038000        70.0       2.127235  Specific Gravity
# 1            60     1.070000        70.0       2.127235  Specific Gravity
# 2            60     1.353955        70.0       2.127235  Specific Gravity
# 3            60     1.353955        70.0       2.127235  Specific Gravity
# 4            90     1.050000        72.0       2.127235  Specific Gravity
# ...         ...          ...         ...            ...               ...
# 73856        60     1.060000        63.0       3.000000  Specific Gravity
# 73857        60     1.034000        60.0       2.127235  Specific Gravity
# 73858        90     1.041000        65.0       2.127235  Specific Gravity
# 73859        60     1.043000        72.0       2.127235  Specific Gravity
# 73860        60     1.056000        70.0       2.127235  Specific Gravity
#
#          BrewMethod  PitchRate  PrimaryTemp
# 0         All Grain   0.750468    17.780000
# 1         All Grain   0.750468    19.175641
# 2           extract   0.750468    19.175641
# 3         All Grain   0.750468    19.175641
# 4         All Grain   0.750468    19.000000
# ...             ...        ...          ...
# 73856     All Grain   1.250000    20.000000
# 73857          BIAB   0.500000    22.000000
# 73858          BIAB   0.350000    17.000000
# 73859     All Grain   0.750468    18.000000
# 73860  Partial Mash   0.750468    18.000000
#
# [73861 rows x 17 columns]

# %%
pd.set_option("display.max_columns", 176)
pd.set_option("max_rows", 176)

# %%
data02 = data.loc[(data['StyleID']==7)|(data['StyleID']==10)|(data['StyleID']==134)\
                  |(data['StyleID']==9)|(data['StyleID']==4)|\
                  (data['StyleID']==30)|(data['StyleID']==86)|(data['StyleID']==12)|\
                 (data['StyleID']==92)|(data['StyleID']==6)|(data['StyleID']==175)|\
                  (data['StyleID']==39)]

# %%
data02
# Out:
#        BeerID  StyleID  Size(L)     OG     FG   ABV     IBU  Color  BoilSize  \
# 2           3        7    18.93  1.063  1.018  5.91   59.25   8.98     22.71
# 3           4        7    22.71  1.061  1.017  5.80   54.48   8.50     26.50
# 5           6       10    24.61  1.055  1.013  5.58   40.12   8.00     29.34
# 6           7       86    22.71  1.072  1.018  7.09  268.71   6.33     30.28
# 9          10       86    20.82  1.080  1.017  8.22   93.02   8.29     28.39
# ...       ...      ...      ...    ...    ...   ...     ...    ...       ...
# 73853   73854        7    18.93  1.073  1.018  7.15    0.00   6.01     22.71
# 73854   73855       10    18.93  1.064  1.016  6.26    0.00   9.60     28.39
# 73855   73856        7    22.71  1.065  1.014  6.71   49.35   4.73     15.14
# 73859   73860       92    24.00  1.051  1.014  4.82   25.65  14.12     28.00
# 73860   73861        7    20.00  1.060  1.010  6.55   57.09   8.65     12.00
#
#        BoilTime  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 2            60     1.353955        70.0       2.127235  Specific Gravity
# 3            60     1.353955        70.0       2.127235  Specific Gravity
# 5            70     1.047000        79.0       2.127235  Specific Gravity
# 6            90     1.353955        75.0       2.127235  Specific Gravity
# 9            60     1.058000        70.0       2.127235  Specific Gravity
# ...         ...          ...         ...            ...               ...
# 73853        60     1.060000        70.0       2.127235  Specific Gravity
# 73854        60     1.042000        75.0       2.127235  Specific Gravity
# 73855        30     1.098000        55.0       2.127235  Specific Gravity
# 73859        60     1.043000        72.0       2.127235  Specific Gravity
# 73860        60     1.056000        70.0       2.127235  Specific Gravity
#
#          BrewMethod  PitchRate  PrimaryTemp
# 2           extract   0.750468    19.175641
# 3         All Grain   0.750468    19.175641
# 5         All Grain   1.000000    19.175641
# 6         All Grain   0.750468    19.175641
# 9         All Grain   0.750468    21.110000
# ...             ...        ...          ...
# 73853          BIAB   0.750468    19.175641
# 73854          BIAB   0.750468    19.175641
# 73855  Partial Mash   0.500000    19.175641
# 73859     All Grain   0.750468    18.000000
# 73860  Partial Mash   0.750468    18.000000
#
# [35424 rows x 17 columns]

# %%
data['SugarScale'].value_counts()
# Out:
# Specific Gravity    71959
# Plato                1902
# Name: SugarScale, dtype: int64

# %%
data['BrewMethod'].value_counts()
# Out:
# All Grain       49692
# BIAB            12016
# extract          8626
# Partial Mash     3527
# Name: BrewMethod, dtype: int64

# %%
SugarScale_encode = pd.get_dummies(data02['SugarScale'])
SugarScale_encode
# Out:
#        Plato  Specific Gravity
# 2          0                 1
# 3          0                 1
# 5          0                 1
# 6          0                 1
# 9          0                 1
# ...      ...               ...
# 73853      0                 1
# 73854      0                 1
# 73855      0                 1
# 73859      0                 1
# 73860      0                 1
#
# [35424 rows x 2 columns]

# %%
BrewMethod_encode = pd.get_dummies(data02['BrewMethod'])
BrewMethod_encode
# Out:
#        All Grain  BIAB  Partial Mash  extract
# 2              0     0             0        1
# 3              1     0             0        0
# 5              1     0             0        0
# 6              1     0             0        0
# 9              1     0             0        0
# ...          ...   ...           ...      ...
# 73853          0     1             0        0
# 73854          0     1             0        0
# 73855          0     0             1        0
# 73859          1     0             0        0
# 73860          0     0             1        0
#
# [35424 rows x 4 columns]

# %%
data03 = pd.concat([data02, SugarScale_encode, BrewMethod_encode], axis = 1)
data03
# Out:
#        BeerID  StyleID  Size(L)     OG     FG   ABV     IBU  Color  BoilSize  \
# 2           3        7    18.93  1.063  1.018  5.91   59.25   8.98     22.71
# 3           4        7    22.71  1.061  1.017  5.80   54.48   8.50     26.50
# 5           6       10    24.61  1.055  1.013  5.58   40.12   8.00     29.34
# 6           7       86    22.71  1.072  1.018  7.09  268.71   6.33     30.28
# 9          10       86    20.82  1.080  1.017  8.22   93.02   8.29     28.39
# ...       ...      ...      ...    ...    ...   ...     ...    ...       ...
# 73853   73854        7    18.93  1.073  1.018  7.15    0.00   6.01     22.71
# 73854   73855       10    18.93  1.064  1.016  6.26    0.00   9.60     28.39
# 73855   73856        7    22.71  1.065  1.014  6.71   49.35   4.73     15.14
# 73859   73860       92    24.00  1.051  1.014  4.82   25.65  14.12     28.00
# 73860   73861        7    20.00  1.060  1.010  6.55   57.09   8.65     12.00
#
#        BoilTime  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 2            60     1.353955        70.0       2.127235  Specific Gravity
# 3            60     1.353955        70.0       2.127235  Specific Gravity
# 5            70     1.047000        79.0       2.127235  Specific Gravity
# 6            90     1.353955        75.0       2.127235  Specific Gravity
# 9            60     1.058000        70.0       2.127235  Specific Gravity
# ...         ...          ...         ...            ...               ...
# 73853        60     1.060000        70.0       2.127235  Specific Gravity
# 73854        60     1.042000        75.0       2.127235  Specific Gravity
# 73855        30     1.098000        55.0       2.127235  Specific Gravity
# 73859        60     1.043000        72.0       2.127235  Specific Gravity
# 73860        60     1.056000        70.0       2.127235  Specific Gravity
#
#          BrewMethod  PitchRate  PrimaryTemp  Plato  Specific Gravity  \
# 2           extract   0.750468    19.175641      0                 1
# 3         All Grain   0.750468    19.175641      0                 1
# 5         All Grain   1.000000    19.175641      0                 1
# 6         All Grain   0.750468    19.175641      0                 1
# 9         All Grain   0.750468    21.110000      0                 1
# ...             ...        ...          ...    ...               ...
# 73853          BIAB   0.750468    19.175641      0                 1
# 73854          BIAB   0.750468    19.175641      0                 1
# 73855  Partial Mash   0.500000    19.175641      0                 1
# 73859     All Grain   0.750468    18.000000      0                 1
# 73860  Partial Mash   0.750468    18.000000      0                 1
#
#        All Grain  BIAB  Partial Mash  extract
# 2              0     0             0        1
# 3              1     0             0        0
# 5              1     0             0        0
# 6              1     0             0        0
# 9              1     0             0        0
# ...          ...   ...           ...      ...
# 73853          0     1             0        0
# 73854          0     1             0        0
# 73855          0     0             1        0
# 73859          1     0             0        0
# 73860          0     0             1        0
#
# [35424 rows x 23 columns]

# %%
data04 = data03.drop(['SugarScale', 'BrewMethod'], axis =1)
data04
# Out:
#        BeerID  StyleID  Size(L)     OG     FG   ABV     IBU  Color  BoilSize  \
# 2           3        7    18.93  1.063  1.018  5.91   59.25   8.98     22.71
# 3           4        7    22.71  1.061  1.017  5.80   54.48   8.50     26.50
# 5           6       10    24.61  1.055  1.013  5.58   40.12   8.00     29.34
# 6           7       86    22.71  1.072  1.018  7.09  268.71   6.33     30.28
# 9          10       86    20.82  1.080  1.017  8.22   93.02   8.29     28.39
# ...       ...      ...      ...    ...    ...   ...     ...    ...       ...
# 73853   73854        7    18.93  1.073  1.018  7.15    0.00   6.01     22.71
# 73854   73855       10    18.93  1.064  1.016  6.26    0.00   9.60     28.39
# 73855   73856        7    22.71  1.065  1.014  6.71   49.35   4.73     15.14
# 73859   73860       92    24.00  1.051  1.014  4.82   25.65  14.12     28.00
# 73860   73861        7    20.00  1.060  1.010  6.55   57.09   8.65     12.00
#
#        BoilTime  BoilGravity  Efficiency  MashThickness  PitchRate  \
# 2            60     1.353955        70.0       2.127235   0.750468
# 3            60     1.353955        70.0       2.127235   0.750468
# 5            70     1.047000        79.0       2.127235   1.000000
# 6            90     1.353955        75.0       2.127235   0.750468
# 9            60     1.058000        70.0       2.127235   0.750468
# ...         ...          ...         ...            ...        ...
# 73853        60     1.060000        70.0       2.127235   0.750468
# 73854        60     1.042000        75.0       2.127235   0.750468
# 73855        30     1.098000        55.0       2.127235   0.500000
# 73859        60     1.043000        72.0       2.127235   0.750468
# 73860        60     1.056000        70.0       2.127235   0.750468
#
#        PrimaryTemp  Plato  Specific Gravity  All Grain  BIAB  Partial Mash  \
# 2        19.175641      0                 1          0     0             0
# 3        19.175641      0                 1          1     0             0
# 5        19.175641      0                 1          1     0             0
# 6        19.175641      0                 1          1     0             0
# 9        21.110000      0                 1          1     0             0
# ...            ...    ...               ...        ...   ...           ...
# 73853    19.175641      0                 1          0     1             0
# 73854    19.175641      0                 1          0     1             0
# 73855    19.175641      0                 1          0     0             1
# 73859    18.000000      0                 1          1     0             0
# 73860    18.000000      0                 1          0     0             1
#
#        extract
# 2            1
# 3            0
# 5            0
# 6            0
# 9            0
# ...        ...
# 73853        0
# 73854        0
# 73855        0
# 73859        0
# 73860        0
#
# [35424 rows x 21 columns]

# %%
data = data04

# %% [markdown]
# # Verifying the best algorithm

# %% [markdown]
# ### Importing the  commom libraries

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Setting the target and predictor variables

# %%
y = data['StyleID']
x = data.drop('StyleID', axis = 1)

# %% [markdown]
# #### Seeting the train and test variables

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %% [markdown]
# ## KNN Algorithm

# %% [markdown]
# #### Importing libraries

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### Normalizing the predictor variables

# %%
normalizer = MinMaxScaler(feature_range = (0, 1))
x_norm = normalizer.fit_transform(x)

# %% [markdown]
# #### Setting the parameter values will be tested

# %%
K_values = np.array([3,5,7,9,11])
distance_calc = ['minkowski', 'chebyshev']
P_values = np.array([1,2,3,4])
grid_values = {'n_neighbors': K_values, 'metric': distance_calc, 'p': P_values}

# %% [markdown]
# #### Creating the model

# %%
model = KNeighborsClassifier()

# %% [markdown]
# #### Creating the grid

# %%
gridKNN = GridSearchCV(estimator = model, param_grid = grid_values, cv = 3, n_jobs = -1)

# %% [markdown]
# #### Applying the grid

# %%
gridKNN.fit(x_norm, y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10324/200833073.py in <module>
# ----> 1 gridKNN.fit(x_norm, y)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1294     def _run_search(self, evaluate_candidates):
#    1295         """Search all candidates in param_grid"""
# -> 1296         evaluate_candidates(ParameterGrid(self.param_grid))
#    1297
#    1298
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Result

# %%
print('Best accuracy: ', gridKNN.best_score_)
print('Best K: ', gridKNN.best_estimator_.n_neighbors)
print('Best distance: ', gridKNN.best_estimator_.metric)
print('Best p value: ', gridKNN.best_estimator_.p)

# %% [markdown]
# ## Naive Bayes

# %% [markdown]
# #### Importing libraries

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# #### Creating the model

# %%
model = GaussianNB()

# %% [markdown]
# #### Applying the model

# %%
skfold = StratifiedKFold(n_splits = 3)
result = cross_val_score(model, x, y, cv = skfold)

# %% [markdown]
# #### Result

# %%
print(f'Accuracy: {result}')

# %%
x_norm
