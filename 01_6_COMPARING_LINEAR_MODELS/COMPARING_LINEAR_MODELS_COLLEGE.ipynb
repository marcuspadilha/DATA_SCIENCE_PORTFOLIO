# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\marcu\Desktop\MACHINE_LEARNING\DATABASES\COLLEGE_SEARCH\Admission_Predict.csv')
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
data.shape
# Out:
# (400, 9)

# %%
data.isnull().count()
# Out:
# Serial No.           400
# GRE Score            400
# TOEFL Score          400
# University Rating    400
# SOP                  400
# LOR                  400
# CGPA                 400
# Research             400
# Chance of Admit      400
# dtype: int64

# %%
data.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
data.rename(columns={'Chance of Admit':'Chance'},inplace=True)

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
y = data['Chance of Admit ']
x = data.drop(['Chance of Admit ','Serial No.'], axis =1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 45)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
linearModel = LinearRegression()
ridgeModel = Ridge()
lassoModel = Lasso()
elasticModel = ElasticNet()
linearModel.fit(x_train, y_train)
ridgeModel.fit(x_train, y_train)
lassoModel.fit(x_train, y_train)
elasticModel.fit(x_train, y_train)
resultLinear = linearModel.score (x_test, y_test)
resultRidge = ridgeModel.score (x_test, y_test)
resultLasso = lassoModel.score (x_test, y_test)
resultElastic = elasticModel.score (x_test, y_test)
resultGeral = {'Linear Score': resultLinear, 'Ridge Score':resultRidge, 'Lasso Score':resultLasso, 'ElasticNet Score':resultElastic}
for i in sorted(resultGeral, key = resultGeral.get, reverse = True):
    print(f'{i}: ', resultGeral[i])
# Out:
# Linear Score:  0.809342876333398
# Ridge Score:  0.8085345281885277
# ElasticNet Score:  0.5647447563640624
# Lasso Score:  0.2855728845758695
