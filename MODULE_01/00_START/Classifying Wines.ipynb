# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\marcu\Desktop\AULAS_ML\DIDATICA_TECH\MACHINE_LEARNING_COURSE\MODULE_00_CLASSIFYING_WINES\wine_dataset.csv')
data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
data.shape
# Out:
# (6497, 13)

# %%
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14044/3048952558.py in <module>
# ----> 1 data.dtypes
#
# NameError: name 'data' is not defined

# %%
data.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11892/1566044817.py in <module>
# ----> 1 data.columns()
#
# TypeError: 'Index' object is not callable

# %%
data['style'] = data['style'].replace('red',0)
data['style'] = data['style'].replace('white',1)

# %%
data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.sum()
# Out:
# fixed_acidity            46877.85000
# volatile_acidity          2206.81000
# citric_acid               2070.16000
# residual_sugar           35364.70000
# chlorides                  364.05200
# free_sulfur_dioxide     198323.00000
# total_sulfur_dioxide    751992.50000
# density                   6462.54403
# pH                       20910.60000
# sulphates                 3451.65000
# alcohol                  68165.23000
# quality                  37802.00000
# style                     4898.00000
# dtype: float64

# %%
y = data['style']
x = data.drop('style', axis = 1)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6492    1
# 6493    1
# 6494    1
# 6495    1
# 6496    1
# Name: style, Length: 6497, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3)

# %%
from sklearn.ensemble import ExtraTreesClassifier
model=ExtraTreesClassifier()
model.fit(x_train,y_train)
# Out:
# ExtraTreesClassifier()

# %%
result = model.score(x_test,y_test)
print(f'Acuracy = {result}')
# Out:
# Acuracy = 0.9984615384615385

# %%
y_test[400:405]
# Out:
# 5855    1
# 331     0
# 6112    1
# 195     0
# 6103    1
# Name: style, dtype: int64

# %%
x_test[400:405]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 5855            6.0              0.33         0.26             5.1      0.051
# 331            10.2              0.36         0.64             2.9      0.122
# 6112            6.8              0.40         0.29             2.8      0.044
# 195             7.8              0.59         0.33             2.0      0.074
# 6103            6.5              0.32         0.23             8.5      0.051
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 5855                 16.0                 119.0  0.99416  3.15       0.41
# 331                  10.0                  41.0  0.99800  3.23       0.66
# 6112                 27.0                  97.0  0.99040  3.12       0.42
# 195                  24.0                 120.0  0.99680  3.25       0.54
# 6103                 20.0                 138.0  0.99430  3.03       0.42
#
#       alcohol  quality
# 5855      9.2        5
# ...

# %%
forecast = model.predict(x_test[400:405])
forecast
# Out:
# array([1, 0, 1, 0, 1], dtype=int64)
